# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt


wdbc_data = pd.read_csv('wdbc.data', header=None)

# Extract features and target (feature #2: class, features 3 to 32: descriptive features)
X = wdbc_data.iloc[:, 2:].values
y = wdbc_data.iloc[:, 1].values  # Target: 'M' for malignant, 'B' for benign

# Standardize the features
scaler = StandardScaler()
X_standardized = scaler.fit_transform(X)

# Create a new DataFrame with the reduced dimensions and target
pca_df = pd.DataFrame(data=X_pca, columns=['PC1', 'PC2'])
pca_df['Target'] = y

# Plot the PCA result with specified shapes and colors for class labels
plt.figure(figsize=(8, 6))
targets = ['M', 'B']  # Malignant, Benign
colors = ['blue', 'red']
markers = ['o', '^']  # Circle for M, Triangle for B

for target, color, marker in zip(targets, colors, markers):
    indices_to_keep = pca_df['Target'] == target
    plt.scatter(pca_df.loc[indices_to_keep, 'PC1'], pca_df.loc[indices_to_keep, 'PC2'], c=color, label=target, marker=marker)

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.title('PCA: Breast Cancer Dataset (2D)')
plt.show()

# %%
# Create a DataFrame with the reduced dimensions and target
pca_result_df = pd.DataFrame(data=X_pca, columns=['PC1', 'PC2'])
pca_result_df['Class'] = y

# Save the DataFrame to a CSV file
pca_result_df.to_csv('wdbc_2D.data', index=False)

print("Dataset wdbc_2D.data saved successfully.")
# Out:
# Dataset wdbc_2D.data saved successfully.
